# %% [markdown]
# # Pandas Task

# %% [markdown]
# 1) Load the dataset into a pandas DataFrame and display the first 5 rows.

# %%
# # Load the dataset
import pandas as pd
dataset_path = "/root/.cache/kagglehub/datasets/spscientist/students-performance-in-exams/versions/1/StudentsPerformance.csv"
data = pd.read_csv(dataset_path)

# %%
# Display the first 5 rows
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# 2) How many students are there in the dataset?

# %%
# Count the number of rows
len(data)
# Out:
# 1000

# %% [markdown]
# 3) What are the unique values in the 'gender' column?

# %%
# Get unique values in the 'gender' column
unique_genders = data['gender'].unique()
print(unique_genders)
# Out:
# ['female' 'male']

# %% [markdown]
# 4) What is the average score in math among female students?

# %%
# Calculate the average math score among female students
average_math_female = data[data['gender'] == 'female']['math score'].mean()
print(average_math_female)
# Out:
# 63.633204633204635

# %% [markdown]
# 5) What is the maximum score in reading among male students?

# %%
# Find the maximum reading score among male students
max_reading_male = data[data['gender'] == 'male']['reading score'].max()
print(max_reading_male)
# Out:
# 100

# %% [markdown]
# 6) Create a new column 'total_score' which sums up the scores of math, reading, and writing for each student.

# %%
# Create a new column 'total_score'
data['total score'] = data['math score'] + data['reading score'] + data['writing score']
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %% [markdown]
# 7) Who scored the highest total marks and what is the score?

# %%
# Find the student with the highest total score
highest_total_score = data.loc[data['total score'].idxmax()]
print(highest_total_score)
# Out:
# gender                                    female
# race/ethnicity                           group E
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                   100
# reading score                                100
# writing score                                100
# total score                                  300
# Name: 458, dtype: object

# %% [markdown]
# 8) Calculate the mean, median, and standard deviation of scores in writing.

# %%
# Calculate mean, median, and standard deviation of writing scores
mean_writing = data['writing score'].mean()
median_writing = data['writing score'].median()
std_writing = data['writing score'].std()

print(mean_writing , median_writing , std_writing)
# Out:
# 68.054 69.0 15.195657010869642

# %% [markdown]
# 9) How many students have scored above 90 in all subjects?

# %%
# Count the number of students who scored above 90 in all subjects
len(data[(data['math score'] > 90) & (data['reading score'] > 90) & (data['writing score'] > 90)])
# Out:
# 23

# %% [markdown]
# 10)Create a new column 'pass_status' which contains 'Pass' if the student's total score is greater than or equal to 150, otherwise 'Fail'.

# %%
# Create a new column 'pass_status'
data['pass_status'] = data['total score'].apply(lambda x: 'Pass' if x >= 150 else 'Fail')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score pass_status
# 0          218        Pass
# 1          247        Pass
# 2          278        Pass
# 3          148        Fail
# 4          229        Pass

# %% [markdown]
# 11) How many null values are there in each column of the dataset?

# %%
print(data.isnull().sum())
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# total score                    0
# pass_status                    0
# dtype: int64

# %% [markdown]
# # Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/spscientist/students-performance-in-exams
